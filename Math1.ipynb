# %%
import numpy as np
import matplotlib.pyplot as plt
from pylab import rcParams
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
rcParams['figure.figsize'] = 12, 3

# %%
x = np.linspace(-10, 10, 121)
plt.plot(x, np.cos(x), x, np.cos(2*x))
plt.show()
